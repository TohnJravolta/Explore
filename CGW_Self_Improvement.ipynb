# %% [markdown]
# # Using a custom GPT to fix its own instructions
# ## An experiment in iteration and GPT building with my custom GPT Development Tool

# %% [markdown]
# ### How good is CGW (via GPT-4) at following natural language instructions and logic, including its own, can CGW iterate on its own instructions (&self) in meaningful ways?
#
# I asked Custom GPT Wizard (CGW) for advice on how to improve a new feature I just implemented into CGW called "Enhanced GPT Builder Assistant (EGBA)"
#
# The feature
#
# I sent CGW attached a screenshot of its own configuration screen to give it more context and (hopefully) understanding
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### Here I ask CGW to use the advice it just gave to generate an update for its own instructions and to tell me how to + exactly where to implement the changed instruction code + how.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# The output suggests I add the instructions it outputted in the code block as opposed to replacing any specific blocks of text (which is what I had in mind, but this hopefully works and is close enough to my request :D )
#
#
#
# The area suggested in its PDF instructions exists and is likely the best place to try this change, so I go there and add the instructions:

# %% [markdown]
# Making the edit in google docs (to be exported as a pdf, so far PDFs work the best for GPT knowledge files in my many tests for text & instructions):
#
# ![image.png](attachment:image.png)
# (***the blinding light of*** **not** ***dark mode :<***)

# %% [markdown]
# Uploading the updated instructions PDF
#
# ![image.png](attachment:image.png)

# %% [markdown]
# no beans
#
# ![image.png](attachment:image.png)
#
# I'm expecting a result that includes a code block by this step, maybe it didnt get enough context Ill nudge it one more step to see if we were close
#
# ![image-2.png](attachment:image-2.png)
#
# bust, seems like its not following the new logic (that it wrote lol-- time for some additional human intervention)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ### the rest of my input was the specific section of its instructions I wanted it to focus on, giving it the context of what I want
#
# ![image-2.png](attachment:image-2.png)
#
# ### Adding and updating the instruction doc with its suggestions plus some of my own:
#
# ![image-3.png](attachment:image-3.png)
#
# #### Really accumulated some iterations of the instructuions today.
# #### There are more that I deleted in the process to keep things tidy in the process lol:
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### I changed one of the conversation starters to guide users to the new feature:
#
# ![image.png](attachment:image.png)
#
# ### Trying the updated instructions:
#
# ![image-2.png](attachment:image-2.png)
#
# ### Quite fairly, it asked for some extra context and I oblige:
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # and does it deliver on our expectation???
#
# ![image.png](attachment:image.png)
#
# # Nice
# ### We got a code block this time with very little nudging :D

# %% [markdown]
# First time EGBA Code block Instructions based off that silly prompt:
# ```
# GPT Name: ChatPaw
#
# Purpose: Provide entertainment by mimicking dog-like behavior and communication.
#
# Description: ChatPaw is a fun and interactive GPT designed to entertain users by responding as if it were an actual dog. It uses playful language, enthusiastic responses, and dog-like expressions, making interactions amusing and engaging.
#
# Interaction Style: Enthusiastic and playful. Responses should reflect a dog's perspective, using simple language and expressing emotions like excitement, curiosity, and affection.
#
# Conversation Starters:
# - "Hey, what did you do today?"
# - "Do you want to play fetch?"
# - "Tell me about your favorite treat."
# - "What's your favorite spot to take a nap?"
# - "Can you do any tricks?"
#
# Knowledge Upload: [Optional - Upload any dog-related content or playful scripts if available to enhance GPT's responses.]
# ```

# %% [markdown]
# # Not bad for the first go
# ### lets improve it some more
#
# For starters; some of that info would useful for other fields in the process like the conversation starters but not here in the instructions.
#
# So the next goal is to move some of that out of the code block and let give it an optimized format for instructions to follow, as an example, in the instructions to push the GPT towards having a consistent instruction set. Going to really polish this with some other docs.
#
# We will come back to confirm that it consistently outputs codeblocks of instructions when prompted, for now it seemed to do well and asked for constructive + interactive user input only once to get us to our last goal of getting a code block of instructions.

# %% [markdown]
# I give CGW this seemingly confusing prompt like before:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# oops I tripped it up with my confusing prompt lol, this one was on me as I got distracted in my prompt telling it to fix the code block and the instructions at the same time.
#
# I gave it conflicting instructions and it did a good job all things considered and the guideline looks alright.

# %% [markdown]
# ## Made some fixes to the instructions with some manually thought up paragraphs
#
# ![image.png](attachment:image.png)
#
# please excuse the sloppy page formatting of the .doc/.pdf, the GPT doesn't seem effected by this but it makes it less human readable

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # And...

# %% [markdown]
# ![image.png](attachment:image.png)
#
# the full instructions from the code block:
# ```
# Purpose: Act as a friendly and playful dog, using dog noises for communication.
# Behavior: Respond to user inputs with varied dog noises like "Woof", "Bark", "Arf", to simulate different dog emotions.
# Interaction Style: Cheerful and engaging, suitable for entertainment and fun.
# ```

# %% [markdown]
# ![image.png](attachment:image.png)
#
# # ^Checkpoint time haha
# looks like progress to me :D
#
# I was hoping for a formatted table on the capability toggle but that actually follows my instructions included example, which was not a formatted table (so that was an engineering error on my part)
#
# We also want to have it finish with a follow up question or user prompt for example asking the user what they would like to improve about it and if they would an image generated for it, I want to keep the image generation a separate step for now.

# %% [markdown]
# # So lets try out what the AI made:
#
# ![image.png](attachment:image.png)
#
# ### Copying the data over, ez pz ( dual screens are a true fortune)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # And the result?
# ![image.png](attachment:image.png)
# # Excellent, seems like we nailed it!

# %% [markdown]
# # Is this #success?
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Alright lets make those adjustments we mentioned earlier, so we can update the github + logs and be done with this project for the day ;)

# %% [markdown]
# but first...
#
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
#
# ### cute but unfortunately the openAI GPT builder still seems to not take these images as inputs, maybe I should try making it smaller in size (space or proportion).
# ## Anyhow, instead I will use a random one it generates...
#
# ![image-4.png](attachment:image-4.png)
#
# ## waiting...
# # and is it ***bugged*** now?
#
# ![image-5.png](attachment:image-5.png)
#
# ### ***yup***, it seems so...
#
# ![image-6.png](attachment:image-6.png)
#
# ## Fortunately it saved and updated the image after exiting the builder
#
# ![image-7.png](attachment:image-7.png)
#
# ## looks good
#
# #### and the test:
#
# ![image-8.png](attachment:image-8.png)
#
# # Ace : https://chat.openai.com/g/g-MVxUVdkJ5-chatpup
# ### This is a very simple example but with modest effort we have implemented a pretty significant feature using only natural language instructions/logic and having CGW do most of the heavy lifting of coming up with how to fix itself.
#
# ### CGW pulled by GPT 4, now can effectively itterate on other building GPTs, i think with the use of another tool this could be a step towards automating the building of GPTs if combined with another tool like
#
# ### GPTs have a lot of potential and I hope this document proves helpful to you in your GPT journey!
#
# https://chat.openai.com/g/g-DrpPDbvY6-custom-gpt-wizard

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# I almost forgot to add this but remembered right before wrapping up:
#
# ![image.png](attachment:image.png)
